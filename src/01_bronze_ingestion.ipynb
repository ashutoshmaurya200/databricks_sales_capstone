# %%
from pyspark.sql.functions import*
sales_df = spark.read.option("header","true").option("inferSchema","true").\
csv("/Volumes/workspace/default/capstone_vol/sales_source_1500.csv")
display(sales_df)

sales_df.describe()

sales_df.write.mode("overwrite").option("mergeSchema", "true").saveAsTable("workspace.default.capstone_bronze_sales")
